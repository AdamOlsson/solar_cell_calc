# %%
def parse_csv(path, separator):
    data = {}
    with open(path, "r") as f:
        _ = f.readline()
        while True:
            line = f.readline().strip("\n")
            if not line:
                break        
            date, spot_price = line.split(separator, 1)
            data[date] = np.array(list(map(lambda x: float(x), spot_price.split(";"))))
    return data

import datetime
def compute_earnings_over_month(
    year:int , month: int, power_production_model_kWh, spot_prices_MkWh, 
    system_kWp:float, inverter_kW: float
):
    import calendar
    assert power_production_model_kWh.shape == (24,), \
        "You should pass in the hourly power production for the day in the given month"
    current_date = datetime.datetime(year, month, 1)
    day = datetime.timedelta(days=1)

    earnings_month = 0
    power_sold_month = 0
    power_produced_month = 0
    num_days_in_month = calendar.monthrange(year, month)[1]
    for _ in range(num_days_in_month):
        current_date_key = datetime.datetime.strftime(current_date, "%Y-%m-%d")
        hourly_spot_prices_MkWh = spot_prices_MkWh[current_date_key]
        hourly_spot_price_day_kWh = hourly_spot_prices_MkWh / 1000.0
        
        hourly_power_produced = power_production_model_kWh * system_kWp
        hourly_power_available_for_sale = np.minimum(inverter_kW, hourly_power_produced)
        hourly_earnings = hourly_spot_price_day_kWh * hourly_power_available_for_sale
                
        earnings_day = hourly_earnings.sum()
        power_production_day = hourly_power_produced.sum()
        power_sold_day = hourly_power_available_for_sale.sum()
        
        earnings_month += earnings_day
        power_sold_month += power_sold_day
        power_produced_month += power_production_day
        current_date += day
    
    return earnings_month, power_sold_month, power_produced_month

def compute_earnings_over_year(year:int, power_production_model_kWh, spot_prices_MkWh, 
    system_kWp: float, inverter_size_kW: float
):
    monthly_earnings = []
    monthly_power_sold = []
    monthly_power_produced = []
    for month in range(1,13):
        earnings, power_sold, power_produced = \
            compute_earnings_over_month( \
                year, month, power_production_model_kWh[:,month -1], spot_prices_MkWh, \
                system_kWp, inverter_size_kW)
        
        monthly_earnings.append(earnings)
        monthly_power_sold.append(power_sold)
        monthly_power_produced.append(power_produced)
    return np.array(monthly_earnings), np.array(monthly_power_sold), np.array(monthly_power_produced)

def print_table_row_earnings(year, width, earnings):
    str_year = f"{year}:"
    print(f"{str_year:<5}", "  ".join(f"{v:>{width}.1f}" for v in earnings), f"  {earnings.sum():.1f}")
    
def print_table_row_power(year, width, sold, produced):
    str_year = f"{year}:"
    power_overflow = produced - sold
    print(f"{str_year:<5}", "  ".join(f"{v:>{width}.1f}" for v in sold), f"  {sold.sum():.1f}")
    print("\x1b[34m" + f"{'':<5}", "  ".join(f"{v:>{width}.1f}" for v in power_overflow), f"  {power_overflow.sum():.1f}" + "\x1b[0m")

# %%
def system_1_over_year(year, system_kWp, inverter_kW):
    peak_power_production_of_system = 12
    return compute_earnings_over_year( \
        year, system_1_hourly_production_per_kWp, power_spot_price_SEK_per_MkWh, \
        system_kWp, inverter_kW)

def system_2_over_year(year, system_kWp, inverter_kW):
    peak_power_production_of_system = 12
    return compute_earnings_over_year( \
        year, system_2_hourly_production_per_kWp, power_spot_price_SEK_per_MkWh, \
        system_kWp, inverter_kW)

import numpy as np
system_1_hourly_production_per_kWp = np.load("norm_15_7kWp_system_power_production.npy")
system_2_hourly_production_per_kWp = np.load("norm_12kWp_system_power_production.npy")
power_spot_price_SEK_per_MkWh = parse_csv("elspotprices_sek.csv", ";")

system_peak_prod_kWh = 20
system_inverter_size_kW = 12
system_1_earnings_2016, system_1_power_sold_2016, system_1_power_produced_2016 = system_1_over_year(2016, system_peak_prod_kWh, system_inverter_size_kW)
system_1_earnings_2017, system_1_power_sold_2017, system_1_power_produced_2017 = system_1_over_year(2017, system_peak_prod_kWh, system_inverter_size_kW)
system_1_earnings_2018, system_1_power_sold_2018, system_1_power_produced_2018 = system_1_over_year(2018, system_peak_prod_kWh, system_inverter_size_kW)
system_1_earnings_2019, system_1_power_sold_2019, system_1_power_produced_2019 = system_1_over_year(2019, system_peak_prod_kWh, system_inverter_size_kW)
system_1_earnings_2020, system_1_power_sold_2020, system_1_power_produced_2020 = system_1_over_year(2020, system_peak_prod_kWh, system_inverter_size_kW)
system_1_earnings_2021, system_1_power_sold_2021, system_1_power_produced_2021 = system_1_over_year(2021, system_peak_prod_kWh, system_inverter_size_kW)
system_1_earnings_2022, system_1_power_sold_2022, system_1_power_produced_2022 = system_1_over_year(2022, system_peak_prod_kWh, system_inverter_size_kW)
system_1_earnings_2023, system_1_power_sold_2023, system_1_power_produced_2023 = system_1_over_year(2023, system_peak_prod_kWh, system_inverter_size_kW)

system_2_earnings_2016, system_2_power_sold_2016, system_2_power_produced_2016 = system_2_over_year(2016, system_peak_prod_kWh, system_inverter_size_kW)
system_2_earnings_2017, system_2_power_sold_2017, system_2_power_produced_2017 = system_2_over_year(2017, system_peak_prod_kWh, system_inverter_size_kW)
system_2_earnings_2018, system_2_power_sold_2018, system_2_power_produced_2018 = system_2_over_year(2018, system_peak_prod_kWh, system_inverter_size_kW)
system_2_earnings_2019, system_2_power_sold_2019, system_2_power_produced_2019 = system_2_over_year(2019, system_peak_prod_kWh, system_inverter_size_kW)
system_2_earnings_2020, system_2_power_sold_2020, system_2_power_produced_2020 = system_2_over_year(2020, system_peak_prod_kWh, system_inverter_size_kW)
system_2_earnings_2021, system_2_power_sold_2021, system_2_power_produced_2021 = system_2_over_year(2021, system_peak_prod_kWh, system_inverter_size_kW)
system_2_earnings_2022, system_2_power_sold_2022, system_2_power_produced_2022 = system_2_over_year(2022, system_peak_prod_kWh, system_inverter_size_kW)
system_2_earnings_2023, system_2_power_sold_2023, system_2_power_produced_2023 = system_2_over_year(2023, system_peak_prod_kWh, system_inverter_size_kW)

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec", "SUM"]
years = list(range(2016, 2024))

column_width = 6
header = "Year  " + "  ".join(f"{month:>{column_width}}" for month in months)
table_width = len(header)
print(f"System 1 Earnings (SEK) ({system_peak_prod_kWh}kWp, {system_inverter_size_kW}kW Inverter)\n".center(table_width))
print(header)
print("-" * len(header))
print_table_row_earnings(2016, column_width, system_1_earnings_2016)
print_table_row_earnings(2017, column_width, system_1_earnings_2017)
print_table_row_earnings(2018, column_width, system_1_earnings_2018)
print_table_row_earnings(2019, column_width, system_1_earnings_2019)
print_table_row_earnings(2020, column_width, system_1_earnings_2020)
print_table_row_earnings(2021, column_width, system_1_earnings_2021)
print_table_row_earnings(2022, column_width, system_1_earnings_2022)
print_table_row_earnings(2023, column_width, system_1_earnings_2023)

print("")

header = "Year  " + "  ".join(f"{month:>{column_width}}" for month in months)
table_width = len(header)
print(f"System 1 Power Sold (Black) and Power Produced Overflow (Blue) (kWh) ({system_peak_prod_kWh}kWp, {system_inverter_size_kW}kW Inverter)\n".center(table_width))
print(header)
print("-" * len(header))

print_table_row_power(2016, column_width, system_1_power_sold_2016, system_1_power_produced_2016)
print_table_row_power(2017, column_width, system_1_power_sold_2017, system_1_power_produced_2017)
print_table_row_power(2018, column_width, system_1_power_sold_2018, system_1_power_produced_2018)
print_table_row_power(2019, column_width, system_1_power_sold_2019, system_1_power_produced_2019)
print_table_row_power(2020, column_width, system_1_power_sold_2020, system_1_power_produced_2020)
print_table_row_power(2021, column_width, system_1_power_sold_2021, system_1_power_produced_2021)
print_table_row_power(2022, column_width, system_1_power_sold_2022, system_1_power_produced_2022)
print_table_row_power(2023, column_width, system_1_power_sold_2023, system_1_power_produced_2023)


print("")

print(f"System 2 Earnings (SEK) ({system_peak_prod_kWh}kWp, {system_inverter_size_kW}kW Inverter)\n".center(table_width))
print(header)
print("-" * len(header))
print_table_row_earnings(2016, column_width, system_2_earnings_2016)
print_table_row_earnings(2017, column_width, system_2_earnings_2017)
print_table_row_earnings(2018, column_width, system_2_earnings_2018)
print_table_row_earnings(2019, column_width, system_2_earnings_2019)
print_table_row_earnings(2020, column_width, system_2_earnings_2020)
print_table_row_earnings(2021, column_width, system_2_earnings_2021)
print_table_row_earnings(2022, column_width, system_2_earnings_2022)
print_table_row_earnings(2023, column_width, system_2_earnings_2023)
print("")

header = "Year  " + "  ".join(f"{month:>{column_width}}" for month in months)
table_width = len(header)
print(f"System 2 Power Sold (Black) and Power Produced Overflow (Red) (kWh) ({system_peak_prod_kWh}kWp, {system_inverter_size_kW}kW Inverter)\n".center(table_width))
print(header)
print("-" * len(header))
print_table_row_power(2016, column_width, system_2_power_sold_2016, system_2_power_produced_2016)
print_table_row_power(2017, column_width, system_2_power_sold_2017, system_2_power_produced_2017)
print_table_row_power(2018, column_width, system_2_power_sold_2018, system_2_power_produced_2018)
print_table_row_power(2019, column_width, system_2_power_sold_2019, system_2_power_produced_2019)
print_table_row_power(2020, column_width, system_2_power_sold_2020, system_2_power_produced_2020)
print_table_row_power(2021, column_width, system_2_power_sold_2021, system_2_power_produced_2021)
print_table_row_power(2022, column_width, system_2_power_sold_2022, system_2_power_produced_2022)
print_table_row_power(2023, column_width, system_2_power_sold_2023, system_2_power_produced_2023)
# Out:
#                               System 1 Earnings (SEK) (20kWp, 12kW Inverter)
#
# Year     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug     Sep     Oct     Nov     Dec     SUM
# ------------------------------------------------------------------------------------------------------------
# 2016:  315.9   282.8   450.2   566.9   790.4  1346.2   980.6   902.4   815.0   594.6   395.3   107.1   7547.4
# 2017:  300.0   467.9   662.7   779.6  1028.8  1033.5  1056.6  1001.4  1033.7   499.0   302.0   102.2   8267.4
# 2018:  322.0   589.9  1061.1  1122.6  1271.5  1725.1  1886.8  1682.9  1502.7   755.1   491.3   172.4   12583.4
# 2019:  560.6   690.1   923.8  1180.5  1351.2  1093.7  1274.9  1157.0  1058.8   673.5   424.8   128.0   10517.0
# 2020:  249.1   326.1   364.9   298.7   518.7  1204.7   373.3  1233.5  1082.4   437.4   284.1   126.5   6499.6
# 2021:  525.6   849.4   895.7   979.7  1591.5  1648.3  2176.0  2105.3  2928.8  1313.5   978.7   711.0   16703.4
# ...

# %%
def plot_cum_sum(yearly_earnings, title):
    import matplotlib.pyplot as plt
    x = np.arange(2016, 2024)
    y = np.array(yearly_earnings).cumsum()
    y /= 1000
    
    fig = plt.figure(figsize=(5,5))
    
    plt.plot(x,y)
    plt.title(title)
    plt.grid()
    plt.xlabel("Year")
    plt.ylabel("kkr")
    plt.show()
  

system_1_yearly_earnings = [
    system_1_earnings_2016.sum(),
    system_1_earnings_2017.sum(),
    system_1_earnings_2018.sum(),
    system_1_earnings_2019.sum(),
    system_1_earnings_2020.sum(),
    system_1_earnings_2021.sum(),
    system_1_earnings_2022.sum(),
    system_1_earnings_2023.sum(),
]

system_2_yearly_earnings = [
    system_2_earnings_2016.sum(),
    system_2_earnings_2017.sum(),
    system_2_earnings_2018.sum(),
    system_2_earnings_2019.sum(),
    system_2_earnings_2020.sum(),
    system_2_earnings_2021.sum(),
    system_2_earnings_2022.sum(),
    system_2_earnings_2023.sum(),
]


plot_cum_sum(system_1_yearly_earnings, "System 1 Yearly Earning Accumulated")
plot_cum_sum(system_2_yearly_earnings, "System 2 Yearly Earning Accumulated")
